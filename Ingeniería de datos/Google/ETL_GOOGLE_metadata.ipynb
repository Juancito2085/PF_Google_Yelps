# %%
import os
import json
import pandas as pd
import numpy as np
import warnings
import reverse_geocode
warnings.filterwarnings('ignore')

# %% [markdown]
# # ETL
# La idea en este notebook es realizar las transformaciones correspondientes a los datos de Google Maps, tanto la metadata como los reviews.
#
# En este caso el alcance se limita a los 5 estados con mayor población California, Nueva York, Texas, Pensilvania y Florida. En cuanto a lo estudiado va a ser la categoria restaurantes, incluyendo todo tipo de los mismos.

# %%
#Generamos un diccionario con las carpetas de los archivos
ruta_review_estados={
    'New_York': 'Datasets/Google Maps/reviews-estados/review-New_York',
    'California': 'Datasets/Google Maps/reviews-estados/review-California',
    'Texas': 'Datasets/Google Maps/reviews-estados/review-Texas',
    'Florida': 'Datasets/Google Maps/reviews-estados/review-Florida',
    'Pennsylvania': 'Datasets/Google Maps/reviews-estados/review-Pennsylvania',

}

# %%
#Creamos un diccionario vacio para almacenar las claves de los reviews para poder filtrar los datos de metadata
gmaps_ids = {}
#Recorremos todas las rutas para cargar los datos de todos los estados
for estado, ruta_estado in ruta_review_estados.items():
#Se utiliza set para evitar duplicados
    gmaps_ids[estado] =set()
    #Se recorren todos los json de las carpetas de los reviews de los estados
    for archivo in os.listdir(ruta_estado):
        ruta_archivo=os.path.join(ruta_estado, archivo)
        with open(ruta_archivo,'r') as file:
            for linea in file:
                data = json.loads(linea)
                gmaps_ids[estado].add(data['gmap_id'])

# %%
#Ruta de la carpeta metadata
ruta_metadata = 'Datasets/Google Maps/metadata-sitios'
#Diccionario para almacenar los datos de metadata
metadata = {}
#Recorremos todos los archivos de la carpeta metadata
for archivo in os.listdir(ruta_metadata):
    ruta_archivo = os.path.join(ruta_metadata, archivo)
    with open(ruta_archivo, 'r',encoding='ISO-8859-1') as file:
        for linea in file:
            data = json.loads(linea)
            #Si el gmap_id esta en el diccionario de gmaps_ids se guarda
            for estado in gmaps_ids.keys():
                if data['gmap_id'] in gmaps_ids[estado]:
                    metadata[data['gmap_id']] = data
                    #Ademas se agrega una columna con el estado al que pertenece
                    metadata[data['gmap_id']]['estado'] = estado

# %%
df_metadata = pd.DataFrame(metadata).T

# %%
df_metadata.reset_index(inplace=True)

# %%
df_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75918 entries, 0 to 75917
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             75918 non-null  object
#  1   name              75917 non-null  object
#  2   address           75041 non-null  object
#  3   gmap_id           75918 non-null  object
#  4   description       7740 non-null   object
#  5   latitude          75918 non-null  object
#  6   longitude         75918 non-null  object
#  7   category          75854 non-null  object
#  8   avg_rating        75918 non-null  object
#  9   num_of_reviews    75918 non-null  object
#  10  price             7494 non-null   object
#  11  hours             65184 non-null  object
#  12  MISC              66495 non-null  object
#  13  state             65855 non-null  object
#  14  relative_results  71555 non-null  object
#  15  url               75918 non-null  object
#  16  estado            75918 non-null  object
# dtypes: object(17)
# memory usage: 9.8+ MB

# %%
df_metadata.isnull().sum()
# Out:
# index                   0
# name                    1
# address               877
# gmap_id                 0
# description         68178
# latitude                0
# longitude               0
# category               64
# avg_rating              0
# num_of_reviews          0
# price               68424
# hours               10734
# MISC                 9423
# state               10063
# relative_results     4363
# url                     0
# estado                  0
# dtype: int64

# %% [markdown]
# Se eliminan todas las columnas que no aportan al proyecto ya sea por gran cantidad de nulos (price,description) o porque son innecesarias.

# %%
df_metadata.drop(columns=['index','description','hours','MISC','relative_results','url','price'],inplace=True)

# %% [markdown]
# Además se eliminan las filas con los valores faltantes en categoría ya que es de suma importancia para el proyecto.

# %%
df_metadata.dropna(subset='category',inplace=True)

# %%
df_metadata.isnull().sum()
# Out:
# name                  1
# address             877
# gmap_id               0
# latitude              0
# longitude             0
# category              0
# avg_rating            0
# num_of_reviews        0
# state             10034
# estado                0
# dtype: int64

# %%
df_metadata.head(3)
# Out:
#                             name  \
# 0                   San Soo Dang
# 1               Nobel Textile Co
# 2  Matrix International Textiles
#
#                                              address  \
# 0  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 1  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# 2  Matrix International Textiles, 1363 S Bonnie B...
#
#                                  gmap_id   latitude   longitude  \
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49  34.058092  -118.29213
# 1  0x80c2c632f933b073:0xc31785961fe826a6  34.036694 -118.249421
# 2  0x80c2cf163db6bc89:0x219484e2edbcfa41  34.015505 -118.181839
#
#               category avg_rating num_of_reviews                 state  \
# 0  [Korean restaurant]        4.4             18     Open ⋅ Closes 6PM
# 1       [Fabric store]        4.3              7     Open ⋅ Closes 5PM
# 2       [Fabric store]        3.5              6  Open ⋅ Closes 5:30PM
#
#        estado
# 0  California
# 1  California
# 2  California

# %% [markdown]
# Vamos a filtrar la información del dataframe por el tipo de negocio que queramos estudiar, en este caso los restaurantes. Por lo que consideramos 2 palabras clave, *restaurant* y *food* para tener las categorías mas importantes.

# %%
df_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75854 entries, 0 to 75917
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            75853 non-null  object
#  1   address         74977 non-null  object
#  2   gmap_id         75854 non-null  object
#  3   latitude        75854 non-null  object
#  4   longitude       75854 non-null  object
#  5   category        75854 non-null  object
#  6   avg_rating      75854 non-null  object
#  7   num_of_reviews  75854 non-null  object
#  8   state           65820 non-null  object
#  9   estado          75854 non-null  object
# dtypes: object(10)
# memory usage: 6.4+ MB

# %%
df_filtered=df_metadata.copy()
#Definimos las palabras claves
palabras_claves = ['restaurant', 'food','steakhouse','mexican','pizzeria','american','asian']
#Expando categoría

#Genero una función para filtrar las palabras claves
def filter_list_by_keywords(lst, palabras_claves):
    return [word for word in lst if any(palabra.lower() in word.lower() for palabra in palabras_claves)]

df_filtered['category'] = df_filtered['category'].apply(lambda x: filter_list_by_keywords(x, palabras_claves))

# %%
df_filtered = df_filtered[df_filtered['category'].apply(lambda x: len(x) > 0)]

# %%
#Verificamos los tipo de datos de categoria
cantidad=df_filtered.explode('category')
cantidad['category'].value_counts()
# Out:
# category
# Restaurant                   2571
# Pizza restaurant              648
# Fast food restaurant          635
# Takeout Restaurant            547
# Mexican restaurant            507
#                              ...
# Japanese curry restaurant       1
# Danish restaurant               1
# Cold noodle restaurant          1
# Nicaraguan restaurant           1
# Belgian restaurant              1
# Name: count, Length: 222, dtype: int64

# %%
df_filtered.reset_index(drop=True, inplace=True)

# %% [markdown]
# Eliminamos a continuación los restaurantes que están permantemente cerrados.

# %%
df_filtered=df_filtered[df_filtered['state']!='Permanently closed']

# %% [markdown]
# Analizamos los duplicados

# %%
df_filtered['gmap_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Como vemos no tenemos dos restaurants con el mismo gmap_id por lo que esto esta en lo correcto.

# %%
df_filtered['name'].duplicated().sum()
# Out:
# 654

# %%
df_filtered[df_filtered['name'].duplicated()]
# Out:
#                      name                                            address  \
# 70             McDonald's  McDonald's, 1000 Palisades Center Dr, West Nya...
# 71             McDonald's        McDonald's, 341 5th Ave, New York, NY 10016
# 91                 Subway  Subway, 230 West Route 59 Store #1, Spring Val...
# 108                Subway  Subway, 1970 Broadway Lower Level, Oakland, CA...
# 186                Subway  Subway, 630 Old Country Road 1105-D, Garden Ci...
# ...                   ...                                                ...
# 6449               Sheetz        Sheetz, 35 E King St, Littlestown, PA 17340
# 6452    Costco Food Court  Costco Food Court, 1875 Hempstead Rd, Lancaste...
# 6463        Golden Dragon  Golden Dragon, 3366 N 2nd St, Philadelphia, PA...
# 6468               Sheetz      Sheetz, 808 N Front St, Philipsburg, PA 16866
# 6471  Crown Fried Chicken  Crown Fried Chicken, 2912 N 22nd St, Philadelp...
#
#                                     gmap_id   latitude   longitude  \
# 70    0x89c2e9cf8e139235:0x24bfb20e9e09f260  41.097768  -73.955392
# 71    0x89c259a9b55adb77:0xfe5e87207e736efc  40.747916  -73.984586
# 91    0x89c2e7f1c5ffad57:0x188085b588f042e3  41.109464  -74.045593
# 108   0x808f80b286dc6f9b:0xb9c0ee0392825cd4  37.808663 -122.268069
# 186   0x89c27d7e84956c31:0x301d481a1d010206  40.738215  -73.612945
# ...                                     ...        ...         ...
# 6449  0x89c84e1c6af47165:0x1776adf5a7b6a69d  39.744958  -77.086867
# 6452  0x89c63b590152cc59:0x443fef10dd8290f4    40.0528  -76.256766
# 6463  0x89c6b7e73fe1610f:0xd01aeaf333ffcbb5  40.002069  -75.132747
# 6468  0x89cc139389a8c0e1:0x96feade8b32f0eb3  40.902906  -78.228924
# 6471   0x89c6c7f7f02bfe15:0xa5ca7c2c7bd545e  39.999072  -75.167054
#
#                                                category avg_rating  \
# 70    [Fast food restaurant, Breakfast restaurant, H...        2.2
# 71                               [Fast food restaurant]        3.1
# 91    [Fast food restaurant, Takeout Restaurant, Res...        3.7
# 108   [Fast food restaurant, Takeout Restaurant, Res...        3.2
# 186   [Fast food restaurant, Takeout Restaurant, Res...        3.5
# ...                                                 ...        ...
# 6449                                       [Restaurant]        3.9
# 6452                                       [Food court]        4.5
# 6463           [Chinese restaurant, Takeout Restaurant]        4.2
# 6468                                       [Restaurant]        3.7
# 6471                                       [Restaurant]        3.7
#
#      num_of_reviews                state        estado
# 70               18                 None      New_York
# 71               16                 None      New_York
# 91               27   Temporarily closed      New_York
# 108              15   Temporarily closed    California
# 186              28   Temporarily closed      New_York
# ...             ...                  ...           ...
# 6449             28        Open 24 hours  Pennsylvania
# 6452             13    Open ⋅ Closes 6PM  Pennsylvania
# 6463             44  Closed ⋅ Opens 12PM  Pennsylvania
# 6468             38        Open 24 hours  Pennsylvania
# 6471             38    Opens soon ⋅ 10AM  Pennsylvania
#
# [654 rows x 10 columns]

# %% [markdown]
# Estos duplicados corresponden a grandes cadenas de comida.

# %%
df_prueba=df_filtered.copy()

# %%
df_prueba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4612 entries, 0 to 6471
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            4612 non-null   object
#  1   address         4603 non-null   object
#  2   gmap_id         4612 non-null   object
#  3   latitude        4612 non-null   object
#  4   longitude       4612 non-null   object
#  5   category        4612 non-null   object
#  6   avg_rating      4612 non-null   object
#  7   num_of_reviews  4612 non-null   object
#  8   state           4178 non-null   object
#  9   estado          4612 non-null   object
# dtypes: object(10)
# memory usage: 396.3+ KB

# %% [markdown]
# Continuaremos con el análisis de la direccion para obtener la ciudad y el codigo postal.

# %%
df_filtered.head()
# Out:
#                   name                                            address  \
# 0         San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 1         Vons Chicken  Vons Chicken, 12740 La Mirada Blvd, La Mirada,...
# 2        Golden Castle    Golden Castle, 1906 E 12th St, Austin, TX 78702
# 3  The Nutrition Group  The Nutrition Group, 5 Interchange Pl, York, P...
# 4  Studio 34 Nutrition  Studio 34 Nutrition, 3021 A, 34th St, Lubbock,...
#
#                                  gmap_id   latitude   longitude  \
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49  34.058092  -118.29213
# 1  0x80dd2b4c8555edb7:0xfc33d65c4bdbef42  33.916402 -118.010855
# 2  0x8644b59b8fe872e5:0x5e638876caa84cc3  30.273985  -97.719563
# 3  0x89c88de475520cc7:0xeff46469445b5212  40.018829  -76.739459
# 4  0x86fe6dd0642d44eb:0xeaceade94f24cc15  33.563039 -101.880718
#
#                    category avg_rating num_of_reviews                 state  \
# 0       [Korean restaurant]        4.4             18     Open ⋅ Closes 6PM
# 1              [Restaurant]        4.5             18  Open ⋅ Closes 9:30PM
# 2              [Restaurant]        4.5              8    Closed ⋅ Opens 5PM
# 3            [Food service]        3.2             17     Open ⋅ Closes 8PM
# 4  [Health food restaurant]          5             14     Open ⋅ Closes 2PM
#
#          estado
# 0    California
# 1    California
# 2         Texas
# 3  Pennsylvania
# 4         Texas

# %%
#Vamos a extraer la ciudad y el código postal de la columna address
df_filtered['city'] = df_filtered['address'].str.extract(r',\s*([^,]+),\s*[A-Z]{2}\s+\d{5}', expand=False)
df_filtered['zip_code'] = df_filtered['address'].str.extract(r'(\d{5})$', expand=False)

# %% [markdown]
# Borramos ahora la columna *state* que no nos sirve mas y verificamos los nulos.

# %%
df_filtered.drop(columns='state', inplace=True)

# %%
df_filtered.isnull().sum()
# Out:
# name               0
# address            9
# gmap_id            0
# latitude           0
# longitude          0
# category           0
# avg_rating         0
# num_of_reviews     0
# estado             0
# city              34
# zip_code          16
# dtype: int64

# %%
#Creamos una funcion para verificar la ciudad y el estado
def get_location(row):
    coordinates = [(row['latitude'], row['longitude'])]
    location = reverse_geocode.search(coordinates)[0]
    if location['country_code'] == 'US':
        return pd.Series([location['city'], location['state']])
    else:
        return pd.Series([None, None])



df_filtered[['city', 'estado']] = df_filtered.apply(get_location, axis=1)

# %%
df_filtered
# Out:
#                             name  \
# 0                   San Soo Dang
# 1                   Vons Chicken
# 2                  Golden Castle
# 3            The Nutrition Group
# 4            Studio 34 Nutrition
# ...                          ...
# 6467                 Burger king
# 6468                      Sheetz
# 6469  Pine View Acres Restaurant
# 6470                Yummy buffet
# 6471         Crown Fried Chicken
#
#                                                 address  \
# 0     San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 1     Vons Chicken, 12740 La Mirada Blvd, La Mirada,...
# 2       Golden Castle, 1906 E 12th St, Austin, TX 78702
# 3     The Nutrition Group, 5 Interchange Pl, York, P...
# 4     Studio 34 Nutrition, 3021 A, 34th St, Lubbock,...
# ...                                                 ...
# 6467  Burger king, 15412 Clearfield Shawville Hwy, C...
# 6468      Sheetz, 808 N Front St, Philipsburg, PA 16866
# 6469  Pine View Acres Restaurant, 145 Chamberlaine A...
# 6470  Yummy buffet, 9351 PA-61, Coal Township, PA 17866
# 6471  Crown Fried Chicken, 2912 N 22nd St, Philadelp...
#
#                                     gmap_id   latitude   longitude  \
# 0     0x80c2c778e3b73d33:0xbdc58662a4a97d49  34.058092  -118.29213
# 1     0x80dd2b4c8555edb7:0xfc33d65c4bdbef42  33.916402 -118.010855
# 2     0x8644b59b8fe872e5:0x5e638876caa84cc3  30.273985  -97.719563
# 3     0x89c88de475520cc7:0xeff46469445b5212  40.018829  -76.739459
# 4     0x86fe6dd0642d44eb:0xeaceade94f24cc15  33.563039 -101.880718
# ...                                     ...        ...         ...
# 6467  0x89cc43bb5c0fc9d7:0x8aa96cda6878befa  41.035812  -78.399347
# 6468  0x89cc139389a8c0e1:0x96feade8b32f0eb3  40.902906  -78.228924
# 6469  0x89c5ec0eca9ada0f:0xc3d9a82aeed859cc  40.701621  -76.184924
# 6470  0x89cf5f469af6fbf7:0xed79fe5afc972b5c  40.790513   -76.50515
# 6471   0x89c6c7f7f02bfe15:0xa5ca7c2c7bd545e  39.999072  -75.167054
#
#                                      category avg_rating num_of_reviews  \
# 0                         [Korean restaurant]        4.4             18
# 1                                [Restaurant]        4.5             18
# 2                                [Restaurant]        4.5              8
# 3                              [Food service]        3.2             17
# 4                    [Health food restaurant]          5             14
# ...                                       ...        ...            ...
# 6467                   [Fast food restaurant]        4.3             13
# 6468                             [Restaurant]        3.7             38
# 6469                     [Seafood restaurant]        3.9             75
# 6470  [Buffet restaurant, Takeout Restaurant]        4.6             45
# 6471                             [Restaurant]        3.7             38
#
#             estado            city zip_code
# 0       California       Koreatown    90005
# 1       California       La Mirada    90638
# 2            Texas          Austin    78702
# 3     Pennsylvania      Emigsville    17406
# 4            Texas         Lubbock    79410
# ...            ...             ...      ...
# 6467  Pennsylvania      Clearfield    16830
# 6468  Pennsylvania     Philipsburg    16866
# 6469  Pennsylvania     Port Carbon    17901
# 6470  Pennsylvania        Kulpmont    17866
# 6471  Pennsylvania  Nicetown-Tioga    19132
#
# [4612 rows x 11 columns]

# %% [markdown]
# Los nulos que quedan se completaran con "Sin Datos" para que el áera de análisis haga su trabajo correspondiente.

# %%
#Completo los nulos con "Sin Datos"
df_filtered.fillna('Sin Datos', inplace=True)

# %%
df_filtered
# Out:
#                             name  \
# 0                   San Soo Dang
# 1                   Vons Chicken
# 2                  Golden Castle
# 3            The Nutrition Group
# 4            Studio 34 Nutrition
# ...                          ...
# 6467                 Burger king
# 6468                      Sheetz
# 6469  Pine View Acres Restaurant
# 6470                Yummy buffet
# 6471         Crown Fried Chicken
#
#                                                 address  \
# 0     San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 1     Vons Chicken, 12740 La Mirada Blvd, La Mirada,...
# 2       Golden Castle, 1906 E 12th St, Austin, TX 78702
# 3     The Nutrition Group, 5 Interchange Pl, York, P...
# 4     Studio 34 Nutrition, 3021 A, 34th St, Lubbock,...
# ...                                                 ...
# 6467  Burger king, 15412 Clearfield Shawville Hwy, C...
# 6468      Sheetz, 808 N Front St, Philipsburg, PA 16866
# 6469  Pine View Acres Restaurant, 145 Chamberlaine A...
# 6470  Yummy buffet, 9351 PA-61, Coal Township, PA 17866
# 6471  Crown Fried Chicken, 2912 N 22nd St, Philadelp...
#
#                                     gmap_id   latitude   longitude  \
# 0     0x80c2c778e3b73d33:0xbdc58662a4a97d49  34.058092 -118.292130
# 1     0x80dd2b4c8555edb7:0xfc33d65c4bdbef42  33.916402 -118.010855
# 2     0x8644b59b8fe872e5:0x5e638876caa84cc3  30.273985  -97.719563
# 3     0x89c88de475520cc7:0xeff46469445b5212  40.018829  -76.739459
# 4     0x86fe6dd0642d44eb:0xeaceade94f24cc15  33.563039 -101.880718
# ...                                     ...        ...         ...
# 6467  0x89cc43bb5c0fc9d7:0x8aa96cda6878befa  41.035812  -78.399347
# 6468  0x89cc139389a8c0e1:0x96feade8b32f0eb3  40.902906  -78.228924
# 6469  0x89c5ec0eca9ada0f:0xc3d9a82aeed859cc  40.701621  -76.184924
# 6470  0x89cf5f469af6fbf7:0xed79fe5afc972b5c  40.790513  -76.505150
# 6471   0x89c6c7f7f02bfe15:0xa5ca7c2c7bd545e  39.999072  -75.167054
#
#                                      category avg_rating num_of_reviews  \
# 0                         [Korean restaurant]        4.4             18
# 1                                [Restaurant]        4.5             18
# 2                                [Restaurant]        4.5              8
# 3                              [Food service]        3.2             17
# 4                    [Health food restaurant]          5             14
# ...                                       ...        ...            ...
# 6467                   [Fast food restaurant]        4.3             13
# 6468                             [Restaurant]        3.7             38
# 6469                     [Seafood restaurant]        3.9             75
# 6470  [Buffet restaurant, Takeout Restaurant]        4.6             45
# 6471                             [Restaurant]        3.7             38
#
#             estado            city zip_code
# 0       California       Koreatown    90005
# 1       California       La Mirada    90638
# 2            Texas          Austin    78702
# 3     Pennsylvania      Emigsville    17406
# 4            Texas         Lubbock    79410
# ...            ...             ...      ...
# 6467  Pennsylvania      Clearfield    16830
# 6468  Pennsylvania     Philipsburg    16866
# 6469  Pennsylvania     Port Carbon    17901
# 6470  Pennsylvania        Kulpmont    17866
# 6471  Pennsylvania  Nicetown-Tioga    19132
#
# [4612 rows x 11 columns]

# %%
#renombo las columnas correspondientes
df_filtered.rename(columns={'estado':'state'},inplace=True)

# %%
#reordeno las columnas
df_filtered = df_filtered[['gmap_id', 'name', 'address', 'city', 'state', 'zip_code', 'latitude', 'longitude', 'category']]

# %%
df_filtered.head()
# Out:
#                                  gmap_id                 name  \
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49         San Soo Dang
# 1  0x80dd2b4c8555edb7:0xfc33d65c4bdbef42         Vons Chicken
# 2  0x8644b59b8fe872e5:0x5e638876caa84cc3        Golden Castle
# 3  0x89c88de475520cc7:0xeff46469445b5212  The Nutrition Group
# 4  0x86fe6dd0642d44eb:0xeaceade94f24cc15  Studio 34 Nutrition
#
#                                              address        city  \
# 0  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...   Koreatown
# 1  Vons Chicken, 12740 La Mirada Blvd, La Mirada,...   La Mirada
# 2    Golden Castle, 1906 E 12th St, Austin, TX 78702      Austin
# 3  The Nutrition Group, 5 Interchange Pl, York, P...  Emigsville
# 4  Studio 34 Nutrition, 3021 A, 34th St, Lubbock,...     Lubbock
#
#           state zip_code   latitude   longitude                  category
# 0    California    90005  34.058092 -118.292130       [Korean restaurant]
# 1    California    90638  33.916402 -118.010855              [Restaurant]
# 2         Texas    78702  30.273985  -97.719563              [Restaurant]
# 3  Pennsylvania    17406  40.018829  -76.739459            [Food service]
# 4         Texas    79410  33.563039 -101.880718  [Health food restaurant]

# %%
#Modifíco la columna state para que contenga la abreviacíon de los estados
def abreviacion_estado(row):
    if row['state'] == 'New York':
        return 'NY'
    elif row['state'] == 'California':
        return 'CA'
    elif row['state'] == 'Texas':
        return 'TX'
    elif row['state'] == 'Florida':
        return 'FL'
    elif row['state'] == 'Pennsylvania':
        return 'PA'
    else:
        return 'Sin Datos'

df_filtered['state'] = df_filtered.apply(abreviacion_estado, axis=1)

# %%
df_restaurantes_clean = df_filtered.copy()

# %%
df_restaurantes_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4612 entries, 0 to 6471
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   gmap_id    4612 non-null   object
#  1   name       4612 non-null   object
#  2   address    4612 non-null   object
#  3   city       4612 non-null   object
#  4   state      4612 non-null   object
#  5   zip_code   4612 non-null   object
#  6   latitude   4612 non-null   float64
#  7   longitude  4612 non-null   float64
#  8   category   4612 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 360.3+ KB

# %%
df_restaurantes_clean.head(3)
# Out:
#                                  gmap_id           name  \
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49   San Soo Dang
# 1  0x80dd2b4c8555edb7:0xfc33d65c4bdbef42   Vons Chicken
# 2  0x8644b59b8fe872e5:0x5e638876caa84cc3  Golden Castle
#
#                                              address       city state  \
# 0  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...  Koreatown    CA
# 1  Vons Chicken, 12740 La Mirada Blvd, La Mirada,...  La Mirada    CA
# 2    Golden Castle, 1906 E 12th St, Austin, TX 78702     Austin    TX
#
#   zip_code   latitude   longitude             category
# 0    90005  34.058092 -118.292130  [Korean restaurant]
# 1    90638  33.916402 -118.010855         [Restaurant]
# 2    78702  30.273985  -97.719563         [Restaurant]

# %%
df_restaurantes_clean.to_parquet('Datos limpios/restaurantes_clean.parquet')

# %%
df_dummies_restaurantes=df_restaurantes_clean[['gmap_id','category']]
categoria=df_dummies_restaurantes['category'].str.get_dummies(sep=',')

# %%
df_dummies_restaurantes=pd.concat([df_dummies_restaurantes,categoria],axis=1)

# %%
df_dummies_restaurantes.reset_index(drop=True, inplace=True)

# %%
df_dummies_restaurantes.to_parquet('Datos limpios/dummies_restaurantes2.parquet')

# %%
df_restaurantes_clean['state'].value_counts()
# Out:
# state
# NY           1349
# PA            920
# CA            897
# TX            809
# FL            624
# Sin Datos      13
# Name: count, dtype: int64
